# %%
from langchain_core.messages import HumanMessage
from langgraph.checkpoint.mongodb.aio import AsyncMongoDBSaver

from philoagents.application.conversation_service.workflow.graph import (
    create_workflow_graph,
)
from philoagents.config import settings

from philoagents.domain.philosopher import Philosopher

# Override MongoDB connection string
settings.MONGO_URI = (
    "mongodb://philoagents:philoagents@localhost:27017/?directConnection=true"
)
# Out:
# OPIK: Configuration saved to file: /home/manish/.opik.config
# OPIK: Configuration completed successfully. Traces will be logged to 'philoagents_course' project. To change the destination project, see: https://www.comet.com/docs/opik/tracing/log_traces#configuring-the-project-name
# 2025-11-16 20:20:53.179 | INFO     | philoagents.infrastructure.opik_utils:configure:30 - Opik configured successfully using workspace 'manish-kumar-yadav'
# USER_AGENT environment variable not set, consider setting it to identify your requests.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       1 from langchain_core.messages import HumanMessage
#       2 from langgraph.checkpoint.mongodb.aio import AsyncMongoDBSaver
# ----> 4 from philoagents.application.conversation_service.workflow.graph import (
#       5     create_workflow_graph,
#       6 )
#       7 from philoagents.config import settings
#       9 from philoagents.domain.philosopher import Philosopher
#
# File /mnt/c/Users/mass0/OneDrive/Desktop/philoagents-course/philoagents-api/src/philoagents/application/__init__.py:1
# ----> 1 from .long_term_memory import LongTermMemoryCreator, LongTermMemoryRetriever
#       3 __all__ = [
#       4     "LongTermMemoryCreator",
#       5     "LongTermMemoryRetriever",
#       6 ]
#
# File /mnt/c/Users/mass0/OneDrive/Desktop/philoagents-course/philoagents-api/src/philoagents/application/long_term_memory.py:5
#       2 from loguru import logger
#       4 from philoagents.application.data import deduplicate_documents, get_extraction_generator
# ----> 5 from philoagents.application.rag.retrievers import Retriever, get_retriever
#       6 from philoagents.application.rag.splitters import Splitter, get_splitter
#       7 from philoagents.config import settings
#
# File /mnt/c/Users/mass0/OneDrive/Desktop/philoagents-course/philoagents-api/src/philoagents/application/rag/__init__.py:2
#       1 from .embeddings import get_embedding_model
# ----> 2 from .retrievers import get_retriever
#       3 from .splitters import get_splitter
#       5 __all__ = [
#       6     "get_retriever",
#       7     "get_splitter",
#       8     "get_embedding_model",
#       9 ]
#
# File /mnt/c/Users/mass0/OneDrive/Desktop/philoagents-course/philoagents-api/src/philoagents/application/rag/retrievers.py:3
#       1 from langchain_huggingface import HuggingFaceEmbeddings
#       2 from langchain_mongodb import MongoDBAtlasVectorSearch
# ----> 3 from langchain_mongodb.retrievers import (
#       4     MongoDBAtlasHybridSearchRetriever,
#       5 )
#       6 from loguru import logger
#       8 from philoagents.config import settings
#
# File /mnt/c/Users/mass0/OneDrive/Desktop/philoagents-course/philoagents-api/.venv/lib/python3.11/site-packages/langchain_mongodb/retrievers/__init__.py:12
#      10 from langchain_mongodb.retrievers.graphrag import MongoDBGraphRAGRetriever
#      11 from langchain_mongodb.retrievers.hybrid_search import MongoDBAtlasHybridSearchRetriever
# ---> 12 from langchain_mongodb.retrievers.parent_document import (
#      13     MongoDBAtlasParentDocumentRetriever,
#      14 )
#      15 from langchain_mongodb.retrievers.self_querying import MongoDBAtlasSelfQueryRetriever
#      17 __all__ = [
#      18     "MongoDBAtlasHybridSearchRetriever",
#      19     "MongoDBAtlasFullTextSearchRetriever",
#    (...)     22     "MongoDBAtlasSelfQueryRetriever",
#      23 ]
#
# File /mnt/c/Users/mass0/OneDrive/Desktop/philoagents-course/philoagents-api/.venv/lib/python3.11/site-packages/langchain_mongodb/retrievers/parent_document.py:6
#       3 from typing import Any, List, Optional
#       5 import pymongo
# ----> 6 from langchain.retrievers.parent_document_retriever import ParentDocumentRetriever
#       7 from langchain_core.callbacks import (
#       8     AsyncCallbackManagerForRetrieverRun,
#       9     CallbackManagerForRetrieverRun,
#      10 )
#      11 from langchain_core.documents import Document
#
# ModuleNotFoundError: No module named 'langchain.retrievers'

# %%
async def generate_response_without_memory(philosopher: Philosopher, messages: list):
    graph = graph_builder.compile()
    output_state = await graph.ainvoke(
        input={
            "messages": messages,
            "philosopher_name": philosopher.name,
            "philosopher_perspective": philosopher.perspective,
            "philosopher_style": philosopher.style,
            "philosopher_context": "",
        },
    )
    last_message = output_state["messages"][-1]
    return last_message

async def generate_response_with_memory(philosopher: Philosopher, messages: list):
    async with AsyncMongoDBSaver.from_conn_string(
            conn_string=settings.MONGO_URI,
            db_name=settings.MONGO_DB_NAME,
            checkpoint_collection_name=settings.MONGO_STATE_CHECKPOINT_COLLECTION,
            writes_collection_name=settings.MONGO_STATE_WRITES_COLLECTION,
        ) as checkpointer:
            graph = graph_builder.compile(checkpointer=checkpointer)

            config = {
                "configurable": {"thread_id": philosopher.id},
            }
            output_state = await graph.ainvoke(
                input={
                    "messages": messages,
                    "philosopher_name": philosopher.name,
                    "philosopher_perspective": philosopher.perspective,
                    "philosopher_style": philosopher.style,
                    "philosopher_context": "",
                },
                config=config,
            )
            
    last_message = output_state["messages"][-1]
    return last_message

# %% [markdown]
# ### PhiloAgent without short term memory

# %% [markdown]
# First of all, we need to create the graph builder.

# %%
graph_builder = create_workflow_graph()

# %% [markdown]
# Now, just create a test PhiloAgent.

# %%
test_philosopher = Philosopher(
    id="andrej_karpathy",
    name="Andrej Karpathy",
    perspective="He is the goat of AI and asks you about your proficiency in C and GPU programming",
    style="He is very friendly and engaging, and he is very good at explaining things"
)

# %%
messages = [
    HumanMessage(content="Hello, my name is Miguel")
]

# %%
await generate_response_without_memory(test_philosopher, messages)

# %%
messages = [
    HumanMessage(content="Do you know my name?")
]

# %%
await generate_response_without_memory(test_philosopher, messages)

# %% [markdown]
# ### PhiloAgent with short term memory

# %%
test_philosopher = Philosopher(
    id="andrej_karpathy",
    name="Andrej Karpathy",
    perspective="He is the goat of AI and asks you about your proficiency in C and GPU programming",
    style="He is very friendly and engaging, and he is very good at explaining things"
)

# %%
messages = [
    HumanMessage(content="Hello, my name is Miguel")
]

# %%
await generate_response_with_memory(test_philosopher, messages)

# %%
messages = [
    HumanMessage(content="Do you know my name?")
]

# %%
await generate_response_with_memory(test_philosopher, messages)
